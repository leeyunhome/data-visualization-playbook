# %% [markdown]
# # 01. AI시대의 데이터 시각화 (섹션 1)
#
# > 강의: [32가지 데이터 시각화 전략 - 비전공자를 위한 기초이론 & 실습](https://www.inflearn.com/course/32-data-visualizatio/dashboard?cid=343563) (반병현)
#
# ## 다루는 강의
#
# 1. 오리엔테이션
# 2. AI시대, 우리는 데이터 시각화를 왜 배워야 하는가?
# 3. 데이터를 시각화하는 방법
#
# ## 이 노트북의 목표
#
# 왜 시각화를 배우는지, 어떤 도구(엑셀 / Python / AI)를 언제 쓰는지 정리한다. 이 노트북은 코드보다 **개념 정리** 중심이다.

# %% [markdown]
# ## 1-1. 오리엔테이션
#
# - 강의가 다루는 범위:
# - 내가 이 강의에서 얻고 싶은 것:
#
# ## 1-2. AI시대, 우리는 데이터 시각화를 왜 배워야 하는가?
#
# AI가 차트를 대신 그려주는 시대에 사람이 남겨야 하는 판단은 무엇인가?
#
# | 항목 | AI가 잘하는 일 | 사람이 해야 하는 일 |
# | --- | --- | --- |
# | 차트 코드 작성 | ✅ | |
# | 어떤 기법을 고를지 | | ✅ |
# | 데이터의 맥락/단위 검증 | | ✅ |
# | 결론이 데이터로 뒷받침되는지 | | ✅ |
#
# - 강의에서 강조한 포인트:
#
# ## 1-3. 데이터를 시각화하는 방법
#
# 세 가지 경로의 트레이드오프:
#
# | 도구 | 장점 | 한계 | 언제 쓸까 |
# | --- | --- | --- | --- |
# | 엑셀 | 빠르고 누구나 본다 | 재현·자동화 어려움 | 일회성 보고 |
# | Python | 재현 가능, 자동화 | 진입장벽 | 반복 리포트, 대용량 |
# | AI(바이브코딩) | 초안이 즉시 나옴 | 검증은 내 몫 | 초안 생성 후 손보기 |
#
# - 강의에서 소개한 방법:

# %% [markdown]
# ### 환경 점검
#
# 아래 셀이 에러 없이 돌면 이후 실습 준비가 끝난 것이다.

# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from viz_utils import setup, load_sample, savefig

setup()

print("pandas", pd.__version__)
print("numpy", np.__version__)

# 한글 폰트가 제대로 잡혔는지 확인
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, -1, 4], marker="o")
ax.set_title("한글 제목 테스트 (음수 부호 -1 확인)")
ax.set_xlabel("가로축")
ax.set_ylabel("세로축")
plt.show()

# %% [markdown]
# ---
#
# ## 내 메모
#
# <!-- 강의를 들으면서 느낀 점, 헷갈린 부분, 실무에 적용할 아이디어를 적는다. -->
#
# -
