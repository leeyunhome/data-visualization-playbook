# %% [markdown]
# # 섹션3-1. 엑셀을 활용한 히스토그램
#
# > 강의: [32가지 데이터 시각화 전략 - 비전공자를 위한 기초이론 & 실습](https://www.inflearn.com/course/32-data-visualizatio/dashboard?cid=343563) (반병현) — 전체 12강
#
# - [x] 강의 시청 완료
# - [ ] 실습/정리 완료
#
# ## 배운 내용
#
# <!-- 강의를 보면서 핵심을 적는다 -->
#
# -
#
# ## 목표 / 재현할 것
#
# <!-- 이 강의에서 만든 차트를 내 방식대로 다시 만들어본다 -->
#
# -

# %% [markdown]
# ## 엑셀 실습
#
# 원본 엑셀 파일은 `data/raw/`에 둔다 (git에는 안 올라감, `.gitignore` 참고).
#
# - 사용한 파일:
# - 만든 차트:
# - 핵심 조작(피벗, 수식 등):

# %% [markdown]
# ### Python으로 재현 (선택)
#
# 엑셀에서 만든 차트를 Python으로도 다시 그려보고 싶으면 아래에 이어간다.

# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from viz_utils import setup, load_sample, savefig

setup()

# 여기에 재현 코드

# %% [markdown]
# ---
#
# ## 메모
#
# -
