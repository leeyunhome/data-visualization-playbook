# %% [markdown]
# # 섹션3-3. Python, VS Code 설치 방법
#
# > 강의: [32가지 데이터 시각화 전략 - 비전공자를 위한 기초이론 & 실습](https://www.inflearn.com/course/32-data-visualizatio/dashboard?cid=343563) (반병현) — 전체 14강
#
# - [x] 강의 시청 완료
# - [ ] 실습/정리 완료
#
# ## 배운 내용
#
# <!-- 강의를 보면서 핵심을 적는다 -->
#
# -
#
# ## 목표 / 재현할 것
#
# <!-- 이 강의에서 만든 차트를 내 방식대로 다시 만들어본다 -->
#
# -

# %% [markdown]
# ## 설치 체크리스트
#
# - [ ] Python 설치 확인 (`python --version`)
# - [ ] VS Code 설치
# - [ ] VS Code Python 확장 설치
# - [ ] Jupyter 커널 연결 확인
#
# 이 저장소는 `.venv`(uv로 생성) + `dataviz-inflearn` 커널을 이미 쓰고 있다.
# 새 컴퓨터에서 다시 세팅할 때만 아래 명령이 필요하다.
#
# ```bash
# uv venv --python 3.12 .venv
# uv pip install -r requirements.txt
# .venv\Scripts\python -m ipykernel install --user --name dataviz-inflearn --display-name "Python (dataviz-inflearn)"
# ```

# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from viz_utils import setup, load_sample, savefig

setup()

print("환경 정상")

# %% [markdown]
# ---
#
# ## 메모
#
# -
